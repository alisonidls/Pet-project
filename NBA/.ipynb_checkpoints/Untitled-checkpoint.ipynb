# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('all_seasons.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'player_name', 'team_abbreviation', 'age',
#        'player_height', 'player_weight', 'college', 'country', 'draft_year',
#        'draft_round', 'draft_number', 'gp', 'pts', 'reb', 'ast', 'net_rating',
#        'oreb_pct', 'dreb_pct', 'usg_pct', 'ts_pct', 'ast_pct', 'season'],
#       dtype='object')

# %%
df = df.drop(['Unnamed: 0',],axis=1)

# %%
df.head()
# Out:
#          player_name team_abbreviation   age  player_height  player_weight  \
# 0      Dennis Rodman               CHI  36.0         198.12      99.790240
# 1  Dwayne Schintzius               LAC  28.0         215.90     117.933920
# 2       Earl Cureton               TOR  39.0         205.74      95.254320
# 3        Ed O'Bannon               DAL  24.0         203.20     100.697424
# 4        Ed Pinckney               MIA  34.0         205.74     108.862080
#
#                        college country draft_year draft_round draft_number  \
# 0  Southeastern Oklahoma State     USA       1986           2           27
# 1                      Florida     USA       1990           1           24
# 2                Detroit Mercy     USA       1979           3           58
# 3                         UCLA     USA       1995           1            9
# 4                    Villanova     USA       1985           1           10
#
# ...

# %%
df.dtypes
# Out:
# player_name           object
# team_abbreviation     object
# age                  float64
# player_height        float64
# player_weight        float64
# college               object
# country               object
# draft_year            object
# draft_round           object
# draft_number          object
# gp                     int64
# pts                  float64
# reb                  float64
# ast                  float64
# net_rating           float64
# oreb_pct             float64
# dreb_pct             float64
# usg_pct              float64
# ts_pct               float64
# ast_pct              float64
# season                object
# dtype: object

# %%
df.isnull().sum()
# Out:
# player_name          0
# team_abbreviation    0
# age                  0
# player_height        0
# player_weight        0
# college              0
# country              0
# draft_year           0
# draft_round          0
# draft_number         0
# gp                   0
# pts                  0
# reb                  0
# ast                  0
# net_rating           0
# oreb_pct             0
# dreb_pct             0
# usg_pct              0
# ts_pct               0
# ast_pct              0
# season               0
# dtype: int64

# %%
df.describe()
# Out:
#                 age  player_height  player_weight            gp           pts  \
# count  12305.000000   12305.000000   12305.000000  12305.000000  12305.000000
# mean      27.084518     200.611602     100.369926     51.290532      8.172775
# std        4.335868       9.146321      12.477150     25.095909      5.974957
# min       18.000000     160.020000      60.327736      1.000000      0.000000
# 25%       24.000000     193.040000      90.718400     31.000000      3.600000
# 50%       26.000000     200.660000      99.790240     57.000000      6.700000
# 75%       30.000000     208.280000     108.862080     73.000000     11.500000
# max       44.000000     231.140000     163.293120     85.000000     36.100000
#
#                 reb           ast    net_rating      oreb_pct      dreb_pct  \
# count  12305.000000  12305.000000  12305.000000  12305.000000  12305.000000
# mean       3.559155      1.813986     -2.255733      0.054473      0.141014
# ...

# %%
plt.figure(figsize=(10,10))
corr = df.corr()
sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,10))
corr = df.corr()
corr = corr[abs(corr) > 0.25]
sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#          player_name team_abbreviation   age  player_height  player_weight  \
# 0      Dennis Rodman               CHI  36.0         198.12      99.790240
# 1  Dwayne Schintzius               LAC  28.0         215.90     117.933920
# 2       Earl Cureton               TOR  39.0         205.74      95.254320
# 3        Ed O'Bannon               DAL  24.0         203.20     100.697424
# 4        Ed Pinckney               MIA  34.0         205.74     108.862080
#
#                        college country draft_year draft_round draft_number  \
# 0  Southeastern Oklahoma State     USA       1986           2           27
# 1                      Florida     USA       1990           1           24
# 2                Detroit Mercy     USA       1979           3           58
# 3                         UCLA     USA       1995           1            9
# 4                    Villanova     USA       1985           1           10
#
# ...

# %%
df.groupby('country', as_index=False) \
    .agg({'player_name':'count'}) \
    .rename(columns={'player_name':'players'}) \
    .sort_values('players', ascending=False) \
    .head(10)
# Out:
#       country  players
# 75        USA    10308
# 12     Canada      182
# 25     France      181
# 2   Australia       89
# 63      Spain       88
# 9      Brazil       85
# 60   Slovenia       73
# 72     Turkey       72
# 16    Croatia       68
# 1   Argentina       65

# %%
df.groupby('college', as_index=False) \
    .agg({'player_name':'count'}) \
    .rename(columns={'player_name':'players'}) \
    .sort_values('players', ascending=False) \
    .head(10)
# Out:
#             college  players
# 190            None     1789
# 125        Kentucky      420
# 76             Duke      384
# 192  North Carolina      344
# 298            UCLA      307
# 9           Arizona      279
# 122          Kansas      278
# 63      Connecticut      230
# 98     Georgia Tech      190
# 84          Florida      188

# %%
df.groupby('season', as_index=False) \
    .agg({'player_height':'mean', 'player_weight':'mean'})
# Out:
#      season  player_height  player_weight
# 0   1996-97     200.994830     100.526270
# 1   1997-98     200.619499     100.265530
# 2   1998-99     200.903007     100.639563
# 3   1999-00     200.920959     100.735741
# 4   2000-01     200.752154     100.842450
# 5   2001-02     201.017909     101.288124
# 6   2002-03     201.520514     102.032765
# 7   2003-04     201.315113     101.635395
# 8   2004-05     201.245733     101.697477
# 9   2005-06     200.920655     101.340178
# 10  2006-07     200.704367     101.329284
# 11  2007-08     200.851486     100.941821
# 12  2008-09     201.196539     101.393611
# 13  2009-10     200.873394     101.140341
# 14  2010-11     201.217832     101.634022
# 15  2011-12     200.832343     101.055087
# 16  2012-13     200.769765     100.872778
# 17  2013-14     200.772946     100.549591
# 18  2014-15     200.838455     100.438213
# 19  2015-16     200.949034     100.414022
# 20  2016-17     200.916790      99.830930
# ...

# %%
plt.figure(figsize=(16,6))
plt.ylim(174, 232) 
ax = sns.boxplot(x="season", y="player_height", data=df, fliersize=0.2, palette=['#48D8D4'])
ax.yaxis.grid(True)
ax.set_xticklabels(ax.get_xticklabels(),rotation = 90);

# %%
plt.figure(figsize=(16,6))
plt.ylim(50, 150) 
ax = sns.boxplot(x="season", y="player_weight", data=df, fliersize=0.2, palette=['#48D8D4'])
ax.yaxis.grid(True)
ax.set_xticklabels(ax.get_xticklabels(),rotation = 90);

# %%
sns.distplot(df.player_height, kde=False)
# Out:
# C:\Users\aliso\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='player_height'>

# %%
sns.distplot(df.player_weight, kde=False)
# Out:
# <AxesSubplot:xlabel='player_weight'>

# %%
df.head()
# Out:
#          player_name team_abbreviation   age  player_height  player_weight  \
# 0      Dennis Rodman               CHI  36.0         198.12      99.790240
# 1  Dwayne Schintzius               LAC  28.0         215.90     117.933920
# 2       Earl Cureton               TOR  39.0         205.74      95.254320
# 3        Ed O'Bannon               DAL  24.0         203.20     100.697424
# 4        Ed Pinckney               MIA  34.0         205.74     108.862080
#
#                        college country draft_year draft_round draft_number  \
# 0  Southeastern Oklahoma State     USA       1986           2           27
# 1                      Florida     USA       1990           1           24
# 2                Detroit Mercy     USA       1979           3           58
# 3                         UCLA     USA       1995           1            9
# 4                    Villanova     USA       1985           1           10
#
# ...

# %%
df.groupby('team_abbreviation', as_index=False) \
    .agg({'pts':'mean', 'reb':'mean', 'ast':'mean'}) \
    .sort_values('pts', ascending=False)
# Out:
#    team_abbreviation       pts       reb       ast
# 22               NOP  8.923270  3.725786  2.041509
# 10               GSW  8.638386  3.775550  2.002200
# 1                BKN  8.573889  3.530556  1.901667
# 14               LAL  8.572263  3.766667  1.928954
# 29               SAC  8.567839  3.669598  1.811307
# 27               PHX  8.512531  3.584712  1.929574
# 11               HOU  8.460766  3.669856  1.776794
# 17               MIL  8.396333  3.629584  1.911736
# 18               MIN  8.392231  3.603759  1.954386
# 8                DEN  8.385437  3.652913  1.890534
# 13               LAC  8.315802  3.533019  1.802830
# 24               OKC  8.291632  3.605439  1.703347
# 21               NOK  8.290625  3.718750  1.493750
# 12               IND  8.278537  3.588780  1.840488
# 16               MIA  8.192958  3.573709  1.779577
# 2                BOS  8.181327  3.517690  1.828993
# 35               WAS  8.165166  3.509716  1.801185
# ...

# %%
df.groupby('team_abbreviation', as_index=False) \
    .agg({'season': pd.Series.nunique}) \
    .sort_values('season', ascending=False)
# Out:
#    team_abbreviation  season
# 0                ATL      26
# 14               LAL      26
# 33               UTA      26
# 32               TOR      26
# 30               SAS      26
# 29               SAC      26
# 28               POR      26
# 27               PHX      26
# 26               PHI      26
# 25               ORL      26
# 23               NYK      26
# 17               MIL      26
# 16               MIA      26
# 18               MIN      26
# 13               LAC      26
# 10               GSW      26
# 2                BOS      26
# 5                CHI      26
# 6                CLE      26
# 7                DAL      26
# 8                DEN      26
# 9                DET      26
# 11               HOU      26
# 12               IND      26
# 35               WAS      26
# 15               MEM      21
# 3                CHA      18
# 19               NJN      16
# 24               OKC      14
# 31               SEA      12
# 1                BKN      10
# ...

# %%
sum_per_season = df.groupby('season', as_index=False) \
    .agg({'pts':'sum', 'reb':'sum', 'ast':'sum'}) \
    .sort_values('season', ascending=True)

# %%
plt.figure(figsize=(16,6))
ax = sns.lineplot(data=sum_per_season, x="season", y="pts")
ax.yaxis.grid(True)

# %%
plt.figure(figsize=(16,6))
ax = sns.lineplot(data=sum_per_season, x="season", y="reb")
ax.yaxis.grid(True)

# %%
plt.figure(figsize=(16,6))
ax = sns.lineplot(data=sum_per_season, x="season", y="ast")
ax.yaxis.grid(True)

# %%
df.head()
# Out:
#          player_name team_abbreviation   age  player_height  player_weight  \
# 0      Dennis Rodman               CHI  36.0         198.12      99.790240
# 1  Dwayne Schintzius               LAC  28.0         215.90     117.933920
# 2       Earl Cureton               TOR  39.0         205.74      95.254320
# 3        Ed O'Bannon               DAL  24.0         203.20     100.697424
# 4        Ed Pinckney               MIA  34.0         205.74     108.862080
#
#                        college country draft_year draft_round draft_number  \
# 0  Southeastern Oklahoma State     USA       1986           2           27
# 1                      Florida     USA       1990           1           24
# 2                Detroit Mercy     USA       1979           3           58
# 3                         UCLA     USA       1995           1            9
# 4                    Villanova     USA       1985           1           10
#
# ...

# %%
list = ['MEM','CHA','NJN','OKC','SEA','BKN','NOP','NOH','CHH','VAN','NOK']

# %%
a = df.query('team_abbreviation in @list').pivot_table(index='season', columns='team_abbreviation', values='pts', aggfunc='sum')
a.plot(figsize=(20,10), grid=True, title='text')
plt.show()

# %%
df.head()
# Out:
#          player_name team_abbreviation   age  player_height  player_weight  \
# 0      Dennis Rodman               CHI  36.0         198.12      99.790240
# 1  Dwayne Schintzius               LAC  28.0         215.90     117.933920
# 2       Earl Cureton               TOR  39.0         205.74      95.254320
# 3        Ed O'Bannon               DAL  24.0         203.20     100.697424
# 4        Ed Pinckney               MIA  34.0         205.74     108.862080
#
#                        college country draft_year draft_round draft_number  \
# 0  Southeastern Oklahoma State     USA       1986           2           27
# 1                      Florida     USA       1990           1           24
# 2                Detroit Mercy     USA       1979           3           58
# 3                         UCLA     USA       1995           1            9
# 4                    Villanova     USA       1985           1           10
#
# ...

# %%
sns.scatterplot(x='player_height', y='player_weight', data = df )
# Out:
# <AxesSubplot:xlabel='player_height', ylabel='player_weight'>

# %%
df[['player_height','player_weight']].corr()
# Out:
#                player_height  player_weight
# player_height       1.000000       0.825421
# player_weight       0.825421       1.000000

# %%
sns.regplot(x='player_height', y='player_weight', data = df)
# Out:
# <AxesSubplot:xlabel='player_height', ylabel='player_weight'>

# %%
from sklearn.linear_model import LinearRegression
linear_regressor = LinearRegression()
linear_regressor.fit(df[['player_height']],df[['player_weight']])
linear_regressor.coef_
# Out:
# array([[1.12601628]])

# %%
# player_weight = 1.12601628 * player_height + C

# %%
sns.boxplot(x="player_weight", data=df)
# Out:
# <AxesSubplot:xlabel='player_weight'>

# %%
sns.boxplot(x="player_height", data=df)
# Out:
# <AxesSubplot:xlabel='player_height'>

# %%
players_draft_year = df[df['draft_year'] == df['season'].apply(lambda x: x[:4])]
lottery_picks = players_draft_year[players_draft_year.draft_number.isin(['1','2','3','4'])]

# %%
lottery_picks.head()
# Out:
#              player_name team_abbreviation   age  player_height  \
# 147        Allen Iverson               PHI  22.0         182.88
# 240  Shareef Abdur-Rahim               VAN  20.0         205.74
# 307      Stephon Marbury               MIN  20.0         187.96
# 424         Marcus Camby               TOR  23.0         210.82
# 520       Keith Van Horn               NJN  22.0         208.28
#
#      player_weight        college country draft_year draft_round draft_number  \
# 147       74.84268     Georgetown     USA       1996           1            1
# 240      104.32616     California     USA       1996           1            3
# 307       81.64656   Georgia Tech     USA       1996           1            4
# 424       99.79024  Massachusetts     USA       1996           1            2
# 520       99.79024           Utah     USA       1997           1            2
#
#      ...   pts  reb  ast  net_rating  oreb_pct  dreb_pct  usg_pct  ts_pct  \
# ...

# %%
team_lottery_picks = lottery_picks['team_abbreviation'].value_counts()
plt.figure(figsize=(15,9))
sns.barplot(team_lottery_picks, team_lottery_picks.index)
# Out:
# C:\Users\aliso\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='team_abbreviation'>

# %%
first_pick = df.query('draft_number == "1"')

# %%
first_pick.groupby('country', as_index=False) \
    .agg({'player_name':'count'}) \
    .sort_values('player_name', ascending=False) \
    .rename(columns={'player_name':'first_pick'})
# Out:
#              country  first_pick
# 8                USA         243
# 0          Australia          29
# 7  US Virgin Islands          19
# 6            Nigeria          15
# 2             Canada          12
# 4              Italy          10
# 3              China           8
# 5            Jamaica           6
# 1            Bahamas           4

# %%
earliest_season = df['season'].unique()[0]
latest_season = df['season'].unique()[-1]

plt.figure(figsize=(16,8))
sns.kdeplot(df[df['season'] == earliest_season]['pts'], color='g', label='1996', linewidth=4)
sns.kdeplot(df[df['season'] == latest_season]['pts'], color='r', label='2021', linewidth= 4)
plt.legend()

# %%
df.head()
# Out:
#          player_name team_abbreviation   age  player_height  player_weight  \
# 0      Dennis Rodman               CHI  36.0         198.12      99.790240
# 1  Dwayne Schintzius               LAC  28.0         215.90     117.933920
# 2       Earl Cureton               TOR  39.0         205.74      95.254320
# 3        Ed O'Bannon               DAL  24.0         203.20     100.697424
# 4        Ed Pinckney               MIA  34.0         205.74     108.862080
#
#                        college country draft_year draft_round draft_number  \
# 0  Southeastern Oklahoma State     USA       1986           2           27
# 1                      Florida     USA       1990           1           24
# 2                Detroit Mercy     USA       1979           3           58
# 3                         UCLA     USA       1995           1            9
# 4                    Villanova     USA       1985           1           10
#
# ...

# %%
df.groupby('season', as_index=False) \
    .agg({'pts':'max', 'ast':'max'})
# Out:
#      season   pts   ast
# 0   1996-97  29.6  11.4
# 1   1997-98  28.7  10.5
# 2   1998-99  26.8  10.8
# 3   1999-00  29.7  10.1
# 4   2000-01  31.1   9.8
# 5   2001-02  31.4  10.9
# 6   2002-03  32.1   8.9
# 7   2003-04  28.0   9.2
# 8   2004-05  30.7  11.5
# 9   2005-06  35.4  10.5
# 10  2006-07  31.6  11.6
# 11  2007-08  30.0  11.6
# 12  2008-09  30.2  11.0
# 13  2009-10  30.1  11.0
# 14  2010-11  27.7  11.4
# 15  2011-12  28.0  11.7
# 16  2012-13  28.7  11.1
# 17  2013-14  32.0  10.7
# 18  2014-15  28.1  10.2
# 19  2015-16  30.1  11.7
# 20  2016-17  31.6  11.2
# 21  2017-18  30.4  10.3
# 22  2018-19  36.1  10.7
# 23  2019-20  34.3  10.2
# 24  2020-21  32.0  11.7
# 25  2021-22  30.6  10.8

# %%
top96 = df.query('season == "1996-97"') \
    .groupby('player_name', as_index=False) \
    .agg({'pts':'max', 'ast':'max', 'reb':'max'}) \
    .sort_values('pts', ascending=False) \
    .head(10)

# %%
top96['total'] = top96.pts+top96.ast+top96.reb

# %%
top96
# Out:
#           player_name   pts  ast   reb  total
# 308    Michael Jordan  29.6  4.3   5.9   39.8
# 243       Karl Malone  27.4  4.5   9.9   41.8
# 178         Glen Rice  26.8  2.0   4.0   32.8
# 378  Shaquille O'Neal  26.2  3.1  12.5   41.8
# 311    Mitch Richmond  25.9  4.2   3.9   34.0
# 267  Latrell Sprewell  24.2  6.3   4.6   35.1
# 9       Allen Iverson  23.5  7.5   4.1   35.1
# 189   Hakeem Olajuwon  23.2  3.0   9.2   35.4
# 326     Patrick Ewing  22.4  2.0  10.7   35.1
# 261    LaPhonso Ellis  21.9  2.4   7.0   31.3

# %%
top96.describe()
# Out:
#             pts        ast       reb      total
# count  10.00000  10.000000  10.00000  10.000000
# mean   25.11000   3.930000   7.18000  36.220000
# std     2.46732   1.833061   3.17728   3.656896
# min    21.90000   2.000000   3.90000  31.300000
# 25%    23.27500   2.550000   4.22500  34.275000
# 50%    25.05000   3.650000   6.45000  35.100000
# 75%    26.65000   4.450000   9.72500  38.700000
# max    29.60000   7.500000  12.50000  41.800000

# %%
top21 = df.query('season == "2021-22"') \
    .groupby('player_name', as_index=False) \
    .agg({'pts':'max', 'ast':'max', 'reb':'max'}) \
    .sort_values('pts', ascending=False) \
    .head(10)

# %%
top21['total'] = top21.pts+top21.ast+top21.reb

# %%
top21
# Out:
#                player_name   pts  ast   reb  total
# 295            Joel Embiid  30.6  4.2  11.7   46.5
# 374           LeBron James  30.3  6.2   8.2   44.7
# 346           Kevin Durant  29.9  6.4   7.4   43.7
# 206  Giannis Antetokounmpo  29.9  5.8  11.6   47.3
# 553             Trae Young  28.4  9.7   3.7   41.8
# 383            Luka Doncic  28.4  8.7   9.1   46.2
# 133          DeMar DeRozan  27.9  4.9   5.2   38.0
# 365           Kyrie Irving  27.4  5.8   4.4   37.6
# 237              Ja Morant  27.4  6.7   5.7   39.8
# 449           Nikola Jokic  27.1  7.9  13.8   48.8

# %%
top21.describe()
# Out:
#              pts        ast        reb      total
# count  10.000000  10.000000  10.000000  10.000000
# mean   28.730000   6.630000   8.080000  43.440000
# std     1.325016   1.694468   3.438604   3.970782
# min    27.100000   4.200000   3.700000  37.600000
# 25%    27.525000   5.800000   5.325000  40.300000
# 50%    28.400000   6.300000   7.800000  44.200000
# 75%    29.900000   7.600000  10.975000  46.425000
# max    30.600000   9.700000  13.800000  48.800000

# %%
df.groupby('player_name', as_index=False) \
    .agg({'pts':'max'}) \
    .rename(columns={'pts':'max_per_season'}) \
    .sort_values('max_per_season', ascending = False) \
    .head(20)
# Out:
#                 player_name  max_per_season
# 1038           James Harden            36.1
# 1414            Kobe Bryant            35.4
# 67            Allen Iverson            33.0
# 2276          Tracy McGrady            32.1
# 1378           Kevin Durant            32.0
# 2153          Stephen Curry            32.0
# 2027      Russell Westbrook            31.6
# 1476           LeBron James            31.4
# 230            Bradley Beal            31.3
# 1197            Joel Embiid            30.6
# 708             Dwyane Wade            30.2
# 477          Damian Lillard            30.0
# 857   Giannis Antetokounmpo            29.9
# 1164       Jerry Stackhouse            29.8
# 2110       Shaquille O'Neal            29.7
# 2279             Trae Young            29.6
# 1677         Michael Jordan            29.6
# 859          Gilbert Arenas            29.3
# 319         Carmelo Anthony            28.9
# 958           Isaiah Thomas            28.9

# %%
df.groupby('player_name', as_index=False) \
    .agg({'ast':'max'}) \
    .rename(columns={'ast':'max_ast_per_season'}) \
    .sort_values('max_ast_per_season', ascending = False) \
    .head(20)
# Out:
#             player_name  max_ast_per_season
# 1910        Rajon Rondo                11.7
# 2027  Russell Westbrook                11.7
# 394          Chris Paul                11.6
# 2166         Steve Nash                11.6
# 1595       Mark Jackson                11.4
# 1038       James Harden                11.2
# 93         Andre Miller                10.9
# 1091         Jason Kidd                10.8
# 1221          John Wall                10.7
# 605      Deron Williams                10.7
# 1985     Rod Strickland                10.5
# 1219      John Stockton                10.5
# 1476       LeBron James                10.2
# 859      Gilbert Arenas                10.0
# 2279         Trae Young                 9.7
# 2320          Ty Lawson                 9.6
# 1384      Kevin Johnson                 9.3
# 581     Dejounte Murray                 9.2
# 1965        Ricky Rubio                 9.1
# 255       Brevin Knight                 9.0

# %%
df.groupby('player_name', as_index=False) \
    .agg({'pts':'mean', 'season':'count'}) \
    .rename(columns={'pts':'average_pts'}) \
    .sort_values('average_pts', ascending = False) \
    .head(20)
# Out:
#                 player_name  average_pts  season
# 1476           LeBron James    27.110526      19
# 1378           Kevin Durant    27.100000      14
# 1516            Luka Doncic    26.525000       4
# 67            Allen Iverson    26.064286      14
# 2279             Trae Young    25.600000       4
# 1197            Joel Embiid    25.450000       6
# 1677         Michael Jordan    25.300000       4
# 1038           James Harden    24.853846      13
# 477          Damian Lillard    24.830000      10
# 2458        Zion Williamson    24.750000       2
# 1414            Kobe Bryant    24.200000      20
# 672        Donovan Mitchell    24.120000       5
# 627            Devin Booker    23.771429       7
# 2153          Stephen Curry    23.761538      13
# 124           Anthony Davis    23.610000      10
# 1329     Karl-Anthony Towns    23.571429       7
# 1440           Kyrie Irving    23.472727      11
# 2027      Russell Westbrook    22.950000      14
# ...

# %%
df.groupby('player_name', as_index=False) \
    .agg({'ast':'mean', 'season':'count'}) \
    .rename(columns={'ast':'average_ast'}) \
    .sort_values('average_ast', ascending = False) \
    .head(20)
# Out:
#             player_name  average_ast  season
# 394          Chris Paul     9.482353      17
# 2279         Trae Young     9.125000       4
# 1221          John Wall     8.880000      10
# 1091         Jason Kidd     8.682353      17
# 1219      John Stockton     8.528571       7
# 2027  Russell Westbrook     8.392857      14
# 2166         Steve Nash     8.161111      18
# 605      Deron Williams     8.025000      12
# 1516        Luka Doncic     8.025000       4
# 1910        Rajon Rondo     7.937500      16
# 2205    Terrell Brandon     7.883333       6
# 188         Ben Simmons     7.700000       4
# 1965        Ricky Rubio     7.627273      11
# 2450     Zavier Simpson     7.500000       1
# 1476       LeBron James     7.368421      19
# 1595       Mark Jackson     7.350000       8
# 2158    Stephon Marbury     7.253846      13
# 180         Baron Davis     7.161538      13
# 979           Ja Morant     7.133333       3
# 1038       James Harden     6.930769      13

# %%
df['total_score'] = df.pts + df.reb + df.ast

# %%
df.head()
# Out:
#          player_name team_abbreviation   age  player_height  player_weight  \
# 0      Dennis Rodman               CHI  36.0         198.12      99.790240
# 1  Dwayne Schintzius               LAC  28.0         215.90     117.933920
# 2       Earl Cureton               TOR  39.0         205.74      95.254320
# 3        Ed O'Bannon               DAL  24.0         203.20     100.697424
# 4        Ed Pinckney               MIA  34.0         205.74     108.862080
#
#                        college country draft_year draft_round draft_number  \
# 0  Southeastern Oklahoma State     USA       1986           2           27
# 1                      Florida     USA       1990           1           24
# 2                Detroit Mercy     USA       1979           3           58
# 3                         UCLA     USA       1995           1            9
# 4                    Villanova     USA       1985           1           10
#
# ...

# %%
df.groupby('player_name', as_index=False) \
    .agg({'total_score':'mean', 'season':'count'}) \
    .rename(columns={'total_score':'average_score'}) \
    .sort_values('average_score', ascending = False) \
    .head(20)
# Out:
#                 player_name  average_score  season
# 1516            Luka Doncic      43.125000       4
# 1476           LeBron James      41.978947      19
# 1197            Joel Embiid      39.666667       6
# 2027      Russell Westbrook      38.750000      14
# 2279             Trae Young      38.625000       4
# 1378           Kevin Durant      38.592857      14
# 1329     Karl-Anthony Towns      38.100000       7
# 1038           James Harden      37.484615      13
# 857   Giannis Antetokounmpo      36.655556       9
# 1791           Nikola Jokic      36.457143       7
# 1328            Karl Malone      36.150000       8
# 124           Anthony Davis      36.120000      10
# 67            Allen Iverson      35.757143      14
# 477          Damian Lillard      35.740000      10
# 1677         Michael Jordan      35.375000       4
# 2153          Stephen Curry      34.838462      13
# 2458        Zion Williamson      34.400000       2
# ...

# %%
df.groupby('player_name', as_index=False) \
    .agg({'total_score':'max'}) \
    .rename(columns={'total_score':'max_total_score'}) \
    .sort_values('max_total_score', ascending = False) \
    .head(20)
# Out:
#                 player_name  max_total_score
# 2027      Russell Westbrook             52.7
# 1038           James Harden             50.2
# 1791           Nikola Jokic             48.8
# 857   Giannis Antetokounmpo             48.7
# 2110       Shaquille O'Neal             47.1
# 1516            Luka Doncic             47.0
# 1197            Joel Embiid             46.5
# 1476           LeBron James             45.6
# 1414            Kobe Bryant             45.2
# 1378           Kevin Durant             44.9
# 2276          Tracy McGrady             44.1
# 67            Allen Iverson             43.6
# 567        DeMarcus Cousins             43.5
# 2153          Stephen Curry             43.3
# 2279             Trae Young             43.2
# 1381          Kevin Garnett             43.1
# 1387             Kevin Love             43.0
# 708             Dwyane Wade             42.7
# 403            Chris Webber             42.4
# 477          Damian Lillard             42.3

# %%
df['bmi'] = round(df.player_weight / ((df.player_height/100)*(df.player_height/100)),2)

# %%
df.head()
# Out:
#          player_name team_abbreviation   age  player_height  player_weight  \
# 0      Dennis Rodman               CHI  36.0         198.12      99.790240
# 1  Dwayne Schintzius               LAC  28.0         215.90     117.933920
# 2       Earl Cureton               TOR  39.0         205.74      95.254320
# 3        Ed O'Bannon               DAL  24.0         203.20     100.697424
# 4        Ed Pinckney               MIA  34.0         205.74     108.862080
#
#                        college country draft_year draft_round draft_number  \
# 0  Southeastern Oklahoma State     USA       1986           2           27
# 1                      Florida     USA       1990           1           24
# 2                Detroit Mercy     USA       1979           3           58
# 3                         UCLA     USA       1995           1            9
# 4                    Villanova     USA       1985           1           10
#
# ...

# %%
qw = df.query('draft_number > "0" & draft_number != "Undrafted"')

# %%
qw.groupby('draft_number', as_index=False) \
    .agg({'pts':'mean'}) \
    .sort_values('pts',ascending=False) \
    .head(20)
# Out:
#    draft_number        pts
# 0             1  16.391040
# 28            3  14.793578
# 50            5  13.006395
# 39            4  12.597006
# 17            2  12.442947
# 66            7  11.467340
# 7            13  11.200382
# 1            10  10.996000
# 73            9  10.867524
# 61            6  10.125893
# 70            8   9.402135
# 22           24   9.375546
# 10           15   9.277632
# 2            11   9.111155
# 14           17   8.961468
# 9            14   8.929439
# 16           19   8.653810
# 58           57   8.554762
# 11           16   8.509767
# 12          160   8.340000
