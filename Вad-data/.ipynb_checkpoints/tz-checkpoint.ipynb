# %%
import pandas as pd
import datetime
import numpy as np

# %%
df = pd.read_csv('dataset_visitors.csv')

# %% [markdown]
#     visit_datetime  – дата и время визита
# 	referrer – ссылка перехода на сайт
# 	visitor_device – устройство посетителя
# 	is_lead – если True то посетитель оставил заявку во время ссесии

# %% [markdown]
#     Задания:
#     1.	Нужно извлечь utm-метки из колонки referrer в итоге в датасете добавятся новых колонки: utm_source, utm_medium, utm_campaign, utm_term, utm_content с соответствующими значениями.
#     2.	Внутри utm_content у некоторых ссылок есть параметр crid, за которым после символа | следует цифра (например: crid|17) – это номер рекламного баннера. Необходимо добавить колонку creative_id в датасет с этими номерами в сессиях в которых они есть.
#     3.	В колонке visitor_device необходимо избавится от словарей, оставив только значение поля “value”.
#     4.	Необходимо добавить колонку channel значение которой будет зависеть от utm_source и referrer:
#     a.	Если referrer пуст, тогда channel = “direct”
#     b.	Если referrer = “https://www.google.com/” тогда channel = “organic”
#     c.	Если utm_source не пуст то берем значение оттуда
#     5.	Добавить колонку week_day в которую на основе даты и visit_date необходимо поместить день недели в формате: Monday, Tuesday..

# %%
df.head()
# Out:
#                    visit_date                 referrer  \
# 0  2021-03-27 10:38:19.482951                      NaN
# 1  2021-03-10 12:50:36.680002                      NaN
# 2  2021-03-05 19:53:09.428238                      NaN
# 3  2021-03-08 10:15:12.315905                      NaN
# 4  2021-03-17 13:25:55.861624  https://www.google.com/
#
#                               visitor_device is_lead
# 0     {"value": "PC", "value_id": "desktop"}    True
# 1  {"value": "Mobile", "value_id": "mobile"}     NaN
# 2     {"value": "PC", "value_id": "desktop"}     NaN
# 3     {"value": "PC", "value_id": "desktop"}    True
# 4     {"value": "PC", "value_id": "desktop"}    True

# %%
df.shape
# Out:
# (1258, 4)

# %%
# Бегло пробежавшись по списку, видим, что не во всех случаях есть все необходимые utm-метки

# %%
df_new = df.query('referrer.notnull()')

# %%
def def1(data):
    return data.replace('?','&')

# %%
df_new['referrer'] = df_new.referrer.apply(def1)
df_new = df_new.query('referrer != "https://www.google.com/"')
# Out:
# C:\Users\aliso\AppData\Local\Temp\ipykernel_4340\3553657898.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['referrer'] = df_new.referrer.apply(def1)

# %%
df_new.head()

# создали новый df со значениями в колонке referrer, которые нам необходимо обработать
# убрали пустые ячейки и ячейки с google.com
# оставили ссылки, в которых есть utm метки
# заменили ? на & для удобства сплита, так как первая метка отделяется "?" по умолчанию.
# Out:
#                     visit_date  \
# 7   2021-03-10 07:16:53.577870
# 17  2021-03-12 16:38:31.863260
# 39  2021-03-26 12:50:36.529962
# 41  2021-03-18 08:23:59.871134
# 44  2021-03-13 12:11:57.159766
#
#                                              referrer  \
# 7   https://callgear.ae/vpbx/&utm_source=google&ut...
# 17  https://callgear.ae/control-employees-lp-oae/m...
# 39  https://callgear.ae/vpbx/&utm_source=google&ut...
# 41  https://callgear.ae/pricing/&cm_id=12187113246...
# 44  https://callgear.ae/vpbx/&utm_source=google&ut...
#
#                                visitor_device is_lead
# 7      {"value": "PC", "value_id": "desktop"}     NaN
# 17  {"value": "Mobile", "value_id": "mobile"}    True
# 39     {"value": "PC", "value_id": "desktop"}     NaN
# 41     {"value": "PC", "value_id": "desktop"}     NaN
# 44     {"value": "PC", "value_id": "desktop"}    True

# %%
df_new['col'] = df_new.referrer.str.split('&utm_')


# разделили значения колонок на нужные нам ячейки

# %%
df_new['utm_source'] = df_new['col'].str[1]
df_new['utm_medium'] = df_new['col'].str[2]
df_new['utm_campaign'] = df_new['col'].str[3]

df_new['utm_source'] = df_new['utm_source'].str.split('=').str[1]
df_new['utm_medium'] = df_new['utm_medium'].str.split('=').str[1]
df_new['utm_campaign'] = df_new['utm_campaign'].str.split('=').str[1]

df_new.head()

# Создаем требуемые колонки, обращаясь к элементам, которые создали в прошлой ячейке.
# Сделали сплит по '=' и обратились к элементу после '=', чтобы избавиться от названия метки в строках

# Проблема заключается в том, что после 'utm_campaign' в некоторых случаях идет 'utm_content', а в других 'utm_term'
# Использование предыдущего метода создаст в одной колонке перемешанные данные
# Out:
#                     visit_date  \
# 7   2021-03-10 07:16:53.577870
# 17  2021-03-12 16:38:31.863260
# 39  2021-03-26 12:50:36.529962
# 41  2021-03-18 08:23:59.871134
# 44  2021-03-13 12:11:57.159766
#
#                                              referrer  \
# 7   https://callgear.ae/vpbx/&utm_source=google&ut...
# 17  https://callgear.ae/control-employees-lp-oae/m...
# 39  https://callgear.ae/vpbx/&utm_source=google&ut...
# 41  https://callgear.ae/pricing/&cm_id=12187113246...
# 44  https://callgear.ae/vpbx/&utm_source=google&ut...
#
#                                visitor_device is_lead  \
# 7      {"value": "PC", "value_id": "desktop"}     NaN
# 17  {"value": "Mobile", "value_id": "mobile"}    True
# 39     {"value": "PC", "value_id": "desktop"}     NaN
# 41     {"value": "PC", "value_id": "desktop"}     NaN
# 44     {"value": "PC", "value_id": "desktop"}    True
#
#                                                   col utm_source utm_medium  \
# 7   [https://callgear.ae/vpbx/, source=google, med...     google        cpc
# 17  [https://callgear.ae/control-employees-lp-oae/...   facebook        cpm
# 39  [https://callgear.ae/vpbx/, source=google, med...     google        cpc
# 41  [https://callgear.ae/pricing/&cm_id=1218711324...     google        cpc
# 44  [https://callgear.ae/vpbx/, source=google, med...     google        cpc
#
#                                          utm_campaign
# 7     GAW_UAE_DU_SEARCH_VP_TR_Key_NewPage|12187113246
# 17  FB_UAE_ALL_CONVERSION_GN_AG_J35|23848562300580067
# 39    GAW_UAE_DU_SEARCH_VP_TR_Key_NewPage|12187113246
# 41    GAW_UAE_DU_SEARCH_VP_TR_Key_NewPage|12187113246
# 44    GAW_UAE_DU_SEARCH_VP_TR_Key_NewPage|12187113246

# %%
df_new['newcol'] = df_new.referrer.str.split('&utm_term=')
df_new['newcol'] = df_new['newcol'].str[1]
df_new['newcol'] = df_new.newcol.str.split('&utm_content=').str[0]
df_new = df_new.rename(columns={'newcol':'utm_term'})

# создаем колонку с разделением по '&utm_term='
# берем [1] элемент, чтобы вытащить значение utm_term
# в некоторых случаях в строке после utm_term идет utm_content
# делаем сплит и берем [0] элемент, чтобы оставить в колонке только значения utm_tem

# %%
df_new
# Out:
#                       visit_date  \
# 7     2021-03-10 07:16:53.577870
# 17    2021-03-12 16:38:31.863260
# 39    2021-03-26 12:50:36.529962
# 41    2021-03-18 08:23:59.871134
# 44    2021-03-13 12:11:57.159766
# ...                          ...
# 1245  2021-03-02 21:52:28.523109
# 1246  2021-03-25 23:08:05.975038
# 1248  2021-03-24 01:04:22.813035
# 1250  2021-03-18 18:34:20.057726
# 1252  2021-03-16 12:44:25.596576
#
#                                                referrer  \
# 7     https://callgear.ae/vpbx/&utm_source=google&ut...
# 17    https://callgear.ae/control-employees-lp-oae/m...
# 39    https://callgear.ae/vpbx/&utm_source=google&ut...
# 41    https://callgear.ae/pricing/&cm_id=12187113246...
# 44    https://callgear.ae/vpbx/&utm_source=google&ut...
# ...                                                 ...
# 1245  https://callgear.ae/control-employees-lp-oae/m...
# 1246  https://callgear.ae/landline-uae-number/up/&ut...
# 1248  https://callgear.ae/missed-calls-lp-oae-2/&utm...
# 1250  https://callgear.ae/missed-calls-lp-oae-2/&utm...
# 1252  https://callgear.ae/control-employees-lp-oae/m...
#
#                                  visitor_device is_lead  \
# 7        {"value": "PC", "value_id": "desktop"}     NaN
# 17    {"value": "Mobile", "value_id": "mobile"}    True
# 39       {"value": "PC", "value_id": "desktop"}     NaN
# 41       {"value": "PC", "value_id": "desktop"}     NaN
# 44       {"value": "PC", "value_id": "desktop"}    True
# ...                                         ...     ...
# 1245  {"value": "Mobile", "value_id": "mobile"}    True
# 1246  {"value": "Mobile", "value_id": "mobile"}    True
# 1248  {"value": "Mobile", "value_id": "mobile"}    True
# 1250  {"value": "Mobile", "value_id": "mobile"}    True
# 1252  {"value": "Mobile", "value_id": "mobile"}    True
#
#                                                     col utm_source utm_medium  \
# 7     [https://callgear.ae/vpbx/, source=google, med...     google        cpc
# 17    [https://callgear.ae/control-employees-lp-oae/...   facebook        cpm
# 39    [https://callgear.ae/vpbx/, source=google, med...     google        cpc
# 41    [https://callgear.ae/pricing/&cm_id=1218711324...     google        cpc
# 44    [https://callgear.ae/vpbx/, source=google, med...     google        cpc
# ...                                                 ...        ...        ...
# 1245  [https://callgear.ae/control-employees-lp-oae/...   facebook        cpm
# 1246  [https://callgear.ae/landline-uae-number/up/, ...   facebook        cpm
# 1248  [https://callgear.ae/missed-calls-lp-oae-2/, s...   facebook        cpm
# 1250  [https://callgear.ae/missed-calls-lp-oae-2/, s...   facebook        cpm
# 1252  [https://callgear.ae/control-employees-lp-oae/...   facebook        cpm
#
#                                            utm_campaign       utm_term
# 7       GAW_UAE_DU_SEARCH_VP_TR_Key_NewPage|12187113246     voip cloud
# 17    FB_UAE_ALL_CONVERSION_GN_AG_J35|23848562300580067            NaN
# 39      GAW_UAE_DU_SEARCH_VP_TR_Key_NewPage|12187113246     voip cloud
# 41      GAW_UAE_DU_SEARCH_VP_TR_Key_NewPage|12187113246    system pabx
# 44      GAW_UAE_DU_SEARCH_VP_TR_Key_NewPage|12187113246  phone virtual
# ...                                                 ...            ...
# 1245  FB_UAE_ALL_CONVERSION_GN_AG_J35|23848562300580067            NaN
# 1246  FB_UAE_ALL_CONVERSION_GN_AG_J34|23848680267780067            NaN
# 1248   FB_UAE_DU_CONVERSION_GN_AG_J35|23848827103510067            NaN
# 1250   FB_UAE_DU_CONVERSION_GN_AG_J35|23848827103510067            NaN
# 1252  FB_UAE_ALL_CONVERSION_GN_AG_J35|23848562300580067            NaN
#
# [553 rows x 9 columns]

# %%
df_new['utm_content'] = df_new.referrer.str.split('&utm_content=')
df_new['utm_content'] = df_new['utm_content'].str[1]
df_new['utm_content'] = df_new.utm_content.str.split('&utm_term=').str[0]

# создаем колонку с разделением по '&utm_content='
# берем [1] элемент, чтобы вытащить значение utm_content
# делаем проверку на наличие в строке 'utm_term' (мало ли)
# делаем сплит и берем [0] элемент, чтобы оставить в колонке только значения utm_content

# %%
df_new = df_new.drop(columns=['visit_date','referrer','visitor_device','is_lead'])
df_new.head()
# Out:
#                                                   col utm_source utm_medium  \
# 7   [https://callgear.ae/vpbx/, source=google, med...     google        cpc
# 17  [https://callgear.ae/control-employees-lp-oae/...   facebook        cpm
# 39  [https://callgear.ae/vpbx/, source=google, med...     google        cpc
# 41  [https://callgear.ae/pricing/&cm_id=1218711324...     google        cpc
# 44  [https://callgear.ae/vpbx/, source=google, med...     google        cpc
#
#                                          utm_campaign       utm_term  \
# 7     GAW_UAE_DU_SEARCH_VP_TR_Key_NewPage|12187113246     voip cloud
# 17  FB_UAE_ALL_CONVERSION_GN_AG_J35|23848562300580067            NaN
# 39    GAW_UAE_DU_SEARCH_VP_TR_Key_NewPage|12187113246     voip cloud
# 41    GAW_UAE_DU_SEARCH_VP_TR_Key_NewPage|12187113246    system pabx
# 44    GAW_UAE_DU_SEARCH_VP_TR_Key_NewPage|12187113246  phone virtual
#
#                                           utm_content
# 7   tid|kwd-13704117858|cid|12187113246|aid|494770...
# 17  cid|23848562300580067|gid|23848562301270067|ai...
# 39  tid|kwd-13704117858|cid|12187113246|aid|494770...
# 41  tid|kwd-351055527567|cid|12187113246|aid|50919...
# 44  tid|kwd-299273384361|cid|12187113246|aid|50919...

# %%
df = df.merge(df_new, how='left', left_index=True, right_index=True)

# добавляем получившиеся колонки в нашу таблицу

# %%
df.head()
# Out:
#                    visit_date                 referrer  \
# 0  2021-03-27 10:38:19.482951                      NaN
# 1  2021-03-10 12:50:36.680002                      NaN
# 2  2021-03-05 19:53:09.428238                      NaN
# 3  2021-03-08 10:15:12.315905                      NaN
# 4  2021-03-17 13:25:55.861624  https://www.google.com/
#
#                               visitor_device is_lead  col utm_source  \
# 0     {"value": "PC", "value_id": "desktop"}    True  NaN        NaN
# 1  {"value": "Mobile", "value_id": "mobile"}     NaN  NaN        NaN
# 2     {"value": "PC", "value_id": "desktop"}     NaN  NaN        NaN
# 3     {"value": "PC", "value_id": "desktop"}    True  NaN        NaN
# 4     {"value": "PC", "value_id": "desktop"}    True  NaN        NaN
#
#   utm_medium utm_campaign utm_term utm_content
# 0        NaN          NaN      NaN         NaN
# 1        NaN          NaN      NaN         NaN
# 2        NaN          NaN      NaN         NaN
# 3        NaN          NaN      NaN         NaN
# 4        NaN          NaN      NaN         NaN

# %%
df['creative_id'] = df.utm_content.str.split('crid').str[1]
df['creative_id'] = df.creative_id.str.split('|').str[1]

# создаем колонку creative_id, в которой будут значения из колонки utm_content после ключа 'crid'
# достаем из полученного значения числа после ключа '|'

# %%
df.head()
# Out:
#                    visit_date                 referrer  \
# 0  2021-03-27 10:38:19.482951                      NaN
# 1  2021-03-10 12:50:36.680002                      NaN
# 2  2021-03-05 19:53:09.428238                      NaN
# 3  2021-03-08 10:15:12.315905                      NaN
# 4  2021-03-17 13:25:55.861624  https://www.google.com/
#
#                               visitor_device is_lead  col utm_source  \
# 0     {"value": "PC", "value_id": "desktop"}    True  NaN        NaN
# 1  {"value": "Mobile", "value_id": "mobile"}     NaN  NaN        NaN
# 2     {"value": "PC", "value_id": "desktop"}     NaN  NaN        NaN
# 3     {"value": "PC", "value_id": "desktop"}    True  NaN        NaN
# 4     {"value": "PC", "value_id": "desktop"}    True  NaN        NaN
#
#   utm_medium utm_campaign utm_term utm_content creative_id
# 0        NaN          NaN      NaN         NaN         NaN
# 1        NaN          NaN      NaN         NaN         NaN
# 2        NaN          NaN      NaN         NaN         NaN
# 3        NaN          NaN      NaN         NaN         NaN
# 4        NaN          NaN      NaN         NaN         NaN

# %%
df['visitor_device'] = df.visitor_device.str.split(':').str[1]
df.visitor_device = df.visitor_device.str.split(',').str[0]

# сплитим значения колонки и вытаскиваем необходимое значение

# %%
df.head()
# Out:
#                    visit_date                 referrer visitor_device is_lead  \
# 0  2021-03-27 10:38:19.482951                      NaN           "PC"    True
# 1  2021-03-10 12:50:36.680002                      NaN       "Mobile"     NaN
# 2  2021-03-05 19:53:09.428238                      NaN           "PC"     NaN
# 3  2021-03-08 10:15:12.315905                      NaN           "PC"    True
# 4  2021-03-17 13:25:55.861624  https://www.google.com/           "PC"    True
#
#    col utm_source utm_medium utm_campaign utm_term utm_content creative_id
# 0  NaN        NaN        NaN          NaN      NaN         NaN         NaN
# 1  NaN        NaN        NaN          NaN      NaN         NaN         NaN
# 2  NaN        NaN        NaN          NaN      NaN         NaN         NaN
# 3  NaN        NaN        NaN          NaN      NaN         NaN         NaN
# 4  NaN        NaN        NaN          NaN      NaN         NaN         NaN

# %%
df.dtypes
# Out:
# visit_date        object
# referrer          object
# visitor_device    object
# is_lead           object
# col               object
# utm_source        object
# utm_medium        object
# utm_campaign      object
# utm_term          object
# utm_content       object
# creative_id       object
# dtype: object

# %%
df['visit_date'] = pd.to_datetime(df['visit_date'])
df['week_day'] = df['visit_date'].dt.day_name()

# переводим колонку 'visit_date' в формат даты
# создаем отдельную колонку 'week_day' с названием дня недели относительно колонки 'visit_date'

# %%
df.head()
# Out:
#                   visit_date                 referrer visitor_device is_lead  \
# 0 2021-03-27 10:38:19.482951                      NaN           "PC"    True
# 1 2021-03-10 12:50:36.680002                      NaN       "Mobile"     NaN
# 2 2021-03-05 19:53:09.428238                      NaN           "PC"     NaN
# 3 2021-03-08 10:15:12.315905                      NaN           "PC"    True
# 4 2021-03-17 13:25:55.861624  https://www.google.com/           "PC"    True
#
#    col utm_source utm_medium utm_campaign utm_term utm_content creative_id  \
# 0  NaN        NaN        NaN          NaN      NaN         NaN         NaN
# 1  NaN        NaN        NaN          NaN      NaN         NaN         NaN
# 2  NaN        NaN        NaN          NaN      NaN         NaN         NaN
# 3  NaN        NaN        NaN          NaN      NaN         NaN         NaN
# 4  NaN        NaN        NaN          NaN      NaN         NaN         NaN
#
#     week_day
# 0   Saturday
# 1  Wednesday
# 2     Friday
# 3     Monday
# 4  Wednesday

# %%
df['channel'] = df.referrer.isnull()
df.loc[(df.referrer == 'NaN'), ('channel')] = 'direct'
df['channel'] = np.where((df.referrer.isnull()), 'direct', df.channel)
df['channel'] = np.where((df.referrer == 'https://www.google.com/'), 'organic', df.channel)

# добавляем условия для значений колонки 'channel' относительно других колонок

# %%
df.head(20)
# Out:
#                    visit_date  \
# 0  2021-03-27 10:38:19.482951
# 1  2021-03-10 12:50:36.680002
# 2  2021-03-05 19:53:09.428238
# 3  2021-03-08 10:15:12.315905
# 4  2021-03-17 13:25:55.861624
# 5  2021-03-23 10:38:49.041414
# 6  2021-03-28 23:16:19.100134
# 7  2021-03-10 07:16:53.577870
# 8  2021-03-23 20:03:21.098973
# 9  2021-03-04 23:16:36.637201
# 10 2021-03-11 15:27:48.953132
# 11 2021-03-17 02:19:57.740003
# 12 2021-03-30 23:13:58.078462
# 13 2021-03-04 20:20:04.640043
# 14 2021-03-12 00:16:15.611361
# 15 2021-03-17 22:28:22.511143
# 16 2021-03-15 14:20:47.991846
# 17 2021-03-12 16:38:31.863260
# 18 2021-03-01 23:11:05.858559
# 19 2021-03-15 15:26:54.359570
#
#                                              referrer visitor_device is_lead  \
# 0                                                 NaN           "PC"    True
# 1                                                 NaN       "Mobile"     NaN
# 2                                                 NaN           "PC"     NaN
# 3                                                 NaN           "PC"    True
# 4                             https://www.google.com/           "PC"    True
# 5                                                 NaN           "PC"     NaN
# 6                                                 NaN           "PC"    True
# 7   https://callgear.ae/vpbx/?utm_source=google&ut...           "PC"     NaN
# 8                             https://www.google.com/           "PC"     NaN
# 9                                                 NaN           null     NaN
# 10                            https://www.google.com/       "Mobile"     NaN
# 11                            https://www.google.com/       "Mobile"    True
# 12                            https://www.google.com/       "Mobile"    True
# 13                                                NaN           "PC"     NaN
# 14                                                NaN           "PC"    True
# 15                                                NaN           "PC"     NaN
# 16                                                NaN           "PC"    True
# 17  https://callgear.ae/control-employees-lp-oae/m...       "Mobile"    True
# 18                            https://www.google.com/           "PC"    True
# 19                                                NaN           null    True
#
#                                                   col utm_source utm_medium  \
# 0                                                 NaN        NaN        NaN
# 1                                                 NaN        NaN        NaN
# 2                                                 NaN        NaN        NaN
# 3                                                 NaN        NaN        NaN
# 4                                                 NaN        NaN        NaN
# 5                                                 NaN        NaN        NaN
# 6                                                 NaN        NaN        NaN
# 7   [https://callgear.ae/vpbx/, source=google, med...     google        cpc
# 8                                                 NaN        NaN        NaN
# 9                                                 NaN        NaN        NaN
# 10                                                NaN        NaN        NaN
# 11                                                NaN        NaN        NaN
# 12                                                NaN        NaN        NaN
# 13                                                NaN        NaN        NaN
# 14                                                NaN        NaN        NaN
# 15                                                NaN        NaN        NaN
# 16                                                NaN        NaN        NaN
# 17  [https://callgear.ae/control-employees-lp-oae/...   facebook        cpm
# 18                                                NaN        NaN        NaN
# 19                                                NaN        NaN        NaN
#
#                                          utm_campaign    utm_term  \
# 0                                                 NaN         NaN
# 1                                                 NaN         NaN
# 2                                                 NaN         NaN
# 3                                                 NaN         NaN
# 4                                                 NaN         NaN
# 5                                                 NaN         NaN
# 6                                                 NaN         NaN
# 7     GAW_UAE_DU_SEARCH_VP_TR_Key_NewPage|12187113246  voip cloud
# 8                                                 NaN         NaN
# 9                                                 NaN         NaN
# 10                                                NaN         NaN
# 11                                                NaN         NaN
# 12                                                NaN         NaN
# 13                                                NaN         NaN
# 14                                                NaN         NaN
# 15                                                NaN         NaN
# 16                                                NaN         NaN
# 17  FB_UAE_ALL_CONVERSION_GN_AG_J35|23848562300580067         NaN
# 18                                                NaN         NaN
# 19                                                NaN         NaN
#
#                                           utm_content creative_id   week_day  \
# 0                                                 NaN         NaN   Saturday
# 1                                                 NaN         NaN  Wednesday
# 2                                                 NaN         NaN     Friday
# 3                                                 NaN         NaN     Monday
# 4                                                 NaN         NaN  Wednesday
# 5                                                 NaN         NaN    Tuesday
# 6                                                 NaN         NaN     Sunday
# 7   tid|kwd-13704117858|cid|12187113246|aid|494770...         NaN  Wednesday
# 8                                                 NaN         NaN    Tuesday
# 9                                                 NaN         NaN   Thursday
# 10                                                NaN         NaN   Thursday
# 11                                                NaN         NaN  Wednesday
# 12                                                NaN         NaN    Tuesday
# 13                                                NaN         NaN   Thursday
# 14                                                NaN         NaN     Friday
# 15                                                NaN         NaN  Wednesday
# 16                                                NaN         NaN     Monday
# 17  cid|23848562300580067|gid|23848562301270067|ai...          91     Friday
# 18                                                NaN         NaN     Monday
# 19                                                NaN         NaN     Monday
#
#     channel
# 0    direct
# 1    direct
# 2    direct
# 3    direct
# 4   organic
# 5    direct
# 6    direct
# 7     False
# 8   organic
# 9    direct
# 10  organic
# 11  organic
# 12  organic
# 13   direct
# 14   direct
# 15   direct
# 16   direct
# 17    False
# 18  organic
# 19   direct

# %%
df['channel'] = np.where((df.utm_source.notnull()), df.utm_source, df.channel)
# добавляем условия для значений колонки 'channel' относительно 'utm_source'

# %%
df = df.drop(columns='col')
# избавляемся от лишних колонок

# %%
df.head()
# Out:
#                   visit_date                 referrer visitor_device is_lead  \
# 0 2021-03-27 10:38:19.482951                      NaN           "PC"    True
# 1 2021-03-10 12:50:36.680002                      NaN       "Mobile"     NaN
# 2 2021-03-05 19:53:09.428238                      NaN           "PC"     NaN
# 3 2021-03-08 10:15:12.315905                      NaN           "PC"    True
# 4 2021-03-17 13:25:55.861624  https://www.google.com/           "PC"    True
#
#   utm_source utm_medium utm_campaign utm_term utm_content creative_id  \
# 0        NaN        NaN          NaN      NaN         NaN         NaN
# 1        NaN        NaN          NaN      NaN         NaN         NaN
# 2        NaN        NaN          NaN      NaN         NaN         NaN
# 3        NaN        NaN          NaN      NaN         NaN         NaN
# 4        NaN        NaN          NaN      NaN         NaN         NaN
#
#     week_day  channel
# 0   Saturday   direct
# 1  Wednesday   direct
# 2     Friday   direct
# 3     Monday   direct
# 4  Wednesday  organic

# %%
df.to_csv('final.csv')
# сохраняем csv файл
